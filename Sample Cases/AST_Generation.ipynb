# %%
import ast

# %% [markdown]
# Binary Search

# %%
# Generate ast of a binary_search

# Must read .py or python program as string datatype first before passing to ast.parse to generate AST obj
file = open("ChatGPT_binary_search.py","r")
text = file.read()
# print(text)

# Create AST object
ast_tree = ast.parse(text)

# Use AST.dump to dump tree; indent parameter indents the tree in "pretty print" format
ast_tree_dump = ast.dump(ast_tree, indent= 4)
print("AST dump:\n",ast_tree_dump)
print("AST dump datatype: ",type(ast_tree_dump)) #It is a is string type
print("AST datatype: ",type(ast_tree)) #It is a is custom <class 'ast.Module'>
# XXXX print("AST datatype: ",ast_tree[0]) #Not using a mode specified in ast.parse will not make a subscriptable obj!!!; 
# Note: Will try to use ast.NodeVisitor class in future
# Out:
# AST dump:
#  Module(
#     body=[
#         FunctionDef(
#             name='binary_search_iterative',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(arg='arr'),
#                     arg(arg='target')],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Assign(
#                     targets=[
#                         Tuple(
#                             elts=[
#                                 Name(id='left', ctx=Store()),
#                                 Name(id='right', ctx=Store())],
#                             ctx=Store())],
#                     value=Tuple(
#                         elts=[
#                             Constant(value=0),
#                             BinOp(
#                                 left=Call(
#                                     func=Name(id='len', ctx=Load()),
#                                     args=[
#                                         Name(id='arr', ctx=Load())],
#                                     keywords=[]),
#                                 op=Sub(),
#                                 right=Constant(value=1))],
#                         ctx=Load())),
#                 While(
#                     test=Compare(
#                         left=Name(id='left', ctx=Load()),
#                         ops=[
#                             LtE()],
#                         comparators=[
#                             Name(id='right', ctx=Load())]),
#                     body=[
#                         Assign(
#                             targets=[
#                                 Name(id='mid', ctx=Store())],
#                             value=BinOp(
#                                 left=BinOp(
#                                     left=Name(id='left', ctx=Load()),
#                                     op=Add(),
#                                     right=Name(id='right', ctx=Load())),
#                                 op=FloorDiv(),
#                                 right=Constant(value=2))),
#                         If(
#                             test=Compare(
#                                 left=Subscript(
#                                     value=Name(id='arr', ctx=Load()),
#                                     slice=Name(id='mid', ctx=Load()),
#                                     ctx=Load()),
#                                 ops=[
#                                     Eq()],
#                                 comparators=[
#                                     Name(id='target', ctx=Load())]),
#                             body=[
#                                 Return(
#                                     value=Name(id='mid', ctx=Load()))],
#                             orelse=[
#                                 If(
#                                     test=Compare(
#                                         left=Subscript(
#                                             value=Name(id='arr', ctx=Load()),
#                                             slice=Name(id='mid', ctx=Load()),
#                                             ctx=Load()),
#                                         ops=[
#                                             Lt()],
#                                         comparators=[
#                                             Name(id='target', ctx=Load())]),
#                                     body=[
#                                         Assign(
#                                             targets=[
#                                                 Name(id='left', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Name(id='mid', ctx=Load()),
#                                                 op=Add(),
#                                                 right=Constant(value=1)))],
#                                     orelse=[
#                                         Assign(
#                                             targets=[
#                                                 Name(id='right', ctx=Store())],
#                                             value=BinOp(
#                                                 left=Name(id='mid', ctx=Load()),
#                                                 op=Sub(),
#                                                 right=Constant(value=1)))])])],
#                     orelse=[]),
#                 Return(
#                     value=UnaryOp(
#                         op=USub(),
#                         operand=Constant(value=1)))],
#             decorator_list=[]),
#         Assign(
#             targets=[
#                 Name(id='arr', ctx=Store())],
#             value=List(
#                 elts=[
#                     Constant(value=2),
#                     Constant(value=3),
#                     Constant(value=4),
#                     Constant(value=10),
#                     Constant(value=40)],
#                 ctx=Load())),
#         Assign(
#             targets=[
#                 Name(id='target', ctx=Store())],
#             value=Constant(value=10)),
#         Assign(
#             targets=[
#                 Name(id='result', ctx=Store())],
#             value=Call(
#                 func=Name(id='binary_search_iterative', ctx=Load()),
#                 args=[
#                     Name(id='arr', ctx=Load()),
#                     Name(id='target', ctx=Load())],
#                 keywords=[])),
#         Expr(
#             value=Call(
#                 func=Name(id='print', ctx=Load()),
#                 args=[
#                     JoinedStr(
#                         values=[
#                             Constant(value='Element found at index: '),
#                             FormattedValue(
#                                 value=Name(id='result', ctx=Load()),
#                                 conversion=-1)])],
#                 keywords=[])),
#         FunctionDef(
#             name='binary_search_recursive',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(arg='arr'),
#                     arg(arg='target'),
#                     arg(arg='left'),
#                     arg(arg='right')],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 If(
#                     test=Compare(
#                         left=Name(id='left', ctx=Load()),
#                         ops=[
#                             Gt()],
#                         comparators=[
#                             Name(id='right', ctx=Load())]),
#                     body=[
#                         Return(
#                             value=UnaryOp(
#                                 op=USub(),
#                                 operand=Constant(value=1)))],
#                     orelse=[]),
#                 Assign(
#                     targets=[
#                         Name(id='mid', ctx=Store())],
#                     value=BinOp(
#                         left=BinOp(
#                             left=Name(id='left', ctx=Load()),
#                             op=Add(),
#                             right=Name(id='right', ctx=Load())),
#                         op=FloorDiv(),
#                         right=Constant(value=2))),
#                 If(
#                     test=Compare(
#                         left=Subscript(
#                             value=Name(id='arr', ctx=Load()),
#                             slice=Name(id='mid', ctx=Load()),
#                             ctx=Load()),
#                         ops=[
#                             Eq()],
#                         comparators=[
#                             Name(id='target', ctx=Load())]),
#                     body=[
#                         Return(
#                             value=Name(id='mid', ctx=Load()))],
#                     orelse=[
#                         If(
#                             test=Compare(
#                                 left=Subscript(
#                                     value=Name(id='arr', ctx=Load()),
#                                     slice=Name(id='mid', ctx=Load()),
#                                     ctx=Load()),
#                                 ops=[
#                                     Lt()],
#                                 comparators=[
#                                     Name(id='target', ctx=Load())]),
#                             body=[
#                                 Return(
#                                     value=Call(
#                                         func=Name(id='binary_search_recursive', ctx=Load()),
#                                         args=[
#                                             Name(id='arr', ctx=Load()),
#                                             Name(id='target', ctx=Load()),
#                                             BinOp(
#                                                 left=Name(id='mid', ctx=Load()),
#                                                 op=Add(),
#                                                 right=Constant(value=1)),
#                                             Name(id='right', ctx=Load())],
#                                         keywords=[]))],
#                             orelse=[
#                                 Return(
#                                     value=Call(
#                                         func=Name(id='binary_search_recursive', ctx=Load()),
#                                         args=[
#                                             Name(id='arr', ctx=Load()),
#                                             Name(id='target', ctx=Load()),
#                                             Name(id='left', ctx=Load()),
#                                             BinOp(
#                                                 left=Name(id='mid', ctx=Load()),
#                                                 op=Sub(),
#                                                 right=Constant(value=1))],
#                                         keywords=[]))])])],
#             decorator_list=[]),
#         Assign(
#             targets=[
#                 Name(id='arr', ctx=Store())],
#             value=List(
#                 elts=[
#                     Constant(value=2),
#                     Constant(value=3),
#                     Constant(value=4),
#                     Constant(value=10),
#                     Constant(value=40)],
#                 ctx=Load())),
#         Assign(
#             targets=[
#                 Name(id='target', ctx=Store())],
#             value=Constant(value=10)),
#         Assign(
#             targets=[
#                 Name(id='result', ctx=Store())],
#             value=Call(
#                 func=Name(id='binary_search_recursive', ctx=Load()),
#                 args=[
#                     Name(id='arr', ctx=Load()),
#                     Name(id='target', ctx=Load()),
#                     Constant(value=0),
#                     BinOp(
#                         left=Call(
#                             func=Name(id='len', ctx=Load()),
#                             args=[
#                                 Name(id='arr', ctx=Load())],
#                             keywords=[]),
#                         op=Sub(),
#                         right=Constant(value=1))],
#                 keywords=[])),
#         Expr(
#             value=Call(
#                 func=Name(id='print', ctx=Load()),
#                 args=[
#                     JoinedStr(
#                         values=[
#                             Constant(value='Element found at index: '),
#                             FormattedValue(
#                                 value=Name(id='result', ctx=Load()),
#                                 conversion=-1)])],
#                 keywords=[]))],
#     type_ignores=[])
# AST dump datatype:  <class 'str'>
# AST datatype:  <class 'ast.Module'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/z0/v38wkxm12_56n9grdgr5sr5m0000gn/T/ipykernel_2690/3123117435.py in <module>
#      14 print("AST dump datatype: ",type(ast_tree_dump)) #It is a is string type
#      15 print("AST datatype: ",type(ast_tree)) #It is a is custom <class 'ast.Module'>
# ---> 16 print("AST datatype: ",ast_tree[0])
#
# TypeError: 'Module' object is not subscriptable

# %% [markdown]
# Explanation:
# Iterative Implementation:
#
#     left and right are the boundaries of the search.
#     The while loop continues as long as left is less than or equal to right.
#     mid is calculated as the middle index of the current search interval.
#     If the target value is found at mid, the function returns the index.
#     If the target value is greater than arr[mid], the search focuses on the right half (left = mid + 1).
#     If the target value is smaller, the search focuses on the left half (right = mid - 1).
#     If the target is not found, -1 is returned.
# Recursive Implementation:
#
#     The function calls itself with a smaller search interval based on the comparison with arr[mid].
#     The base case checks if the search interval is invalid (left > right), meaning the target is not in the array.
#     The process continues recursively until the target is found or the search interval becomes invalid.
# Both implementations assume the input list is sorted.

# %% [markdown]
# Pig Dice Game
# AI/LLM Prompt: Create a python implementation of the Pig Dice Game. Please limit yourself to using as many few libraries as possible.

# %%
# ChatGPT

# %%
# Claude
